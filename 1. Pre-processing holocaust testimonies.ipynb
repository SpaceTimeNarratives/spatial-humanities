# %% [markdown]
# # **Pre-processing a holocaust testimony**

# %% [markdown]
# In this noteboook, we will process a testimony file to extract the `questions` asked as well as the `responses` from the holocaust survivor.
#
# Activities
# 1. Read a testimony transcript file
# 2. Split the transcript into chunks of `question-answer` pairs
# 3. Build a table of all the `sentences` into a data table
